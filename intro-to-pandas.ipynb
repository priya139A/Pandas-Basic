# %%
import pandas as pd

# %%
car_brands=pd.Series(["BMW","Toyato","Benz","Swift","Honda"])

# %%
car_brands
# Out:
# 0       BMW
# 1    Toyato
# 2      Benz
# 3     Swift
# 4     Honda
# dtype: object

# %%
colours=pd.Series(["red","white","blue","black"])
colours
# Out:
# 0      red
# 1    white
# 2     blue
# 3    black
# dtype: object

# %%
car_data=pd.DataFrame({"Car_name":car_brands,"colour":colours})
car_data
# Out:
#   Car_name colour
# 0      BMW    red
# 1   Toyato  white
# 2     Benz   blue
# 3    Swift  black
# 4    Honda    NaN

# %%
#importing data
car_sales=pd.read_csv("car_sales.csv")

# %%
car_sales
# Out:
#   car name  colour  seats       cost
# 0   Toyota     red      4     154000
# 1   Suzuki   black      5     164000
# 2    Honda   white      4    5460000
# 3      BMW    gray      5  100000000
# 4     Audi   white      4     546218
# 5     Nano  yellow      6     543261

# %% [markdown]
# ## Describe Data

# %%
car_sales.dtypes
# Out:
# car name    object
# colour      object
# seats        int64
# cost         int64
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['car name', 'colour', 'seats', 'cost'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
car_sales.describe()
# Out:
#           seats          cost
# count  6.000000  6.000000e+00
# mean   4.666667  1.781125e+07
# std    0.816497  4.031628e+07
# min    4.000000  1.540000e+05
# 25%    4.000000  2.588152e+05
# 50%    4.500000  5.447395e+05
# 75%    5.000000  4.231554e+06
# max    6.000000  1.000000e+08

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   car name  6 non-null      object
#  1   colour    6 non-null      object
#  2   seats     6 non-null      int64
#  3   cost      6 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
car_sales.mean()
# Out:
# seats    4.666667e+00
# cost     1.781125e+07
# dtype: float64

# %%
doors=pd.Series([4,5,4,4,3,5])
doors.mean()
# Out:
# 4.166666666666667

# %%
car_sales["seats"].sum()
# Out:
# 28

# %%
car_sales["cost"].sum()
# Out:
# 106867479

# %%
len(car_sales)
# Out:
# 6

# %%
car_sales
# Out:
#   car name  colour  seats       cost
# 0   Toyota     red      4     154000
# 1   Suzuki   black      5     164000
# 2    Honda   white      4    5460000
# 3      BMW    gray      5  100000000
# 4     Audi   white      4     546218
# 5     Nano  yellow      6     543261

# %% [markdown]
# ## Selecting data and viewing data

# %%
car_sales.head()
# Out:
#   car name colour  seats       cost
# 0   Toyota    red      4     154000
# 1   Suzuki  black      5     164000
# 2    Honda  white      4    5460000
# 3      BMW   gray      5  100000000
# 4     Audi  white      4     546218

# %%
car_sales.tail()
# Out:
#   car name  colour  seats       cost
# 1   Suzuki   black      5     164000
# 2    Honda   white      4    5460000
# 3      BMW    gray      5  100000000
# 4     Audi   white      4     546218
# 5     Nano  yellow      6     543261

# %%
car_sales.head(3)
# Out:
#   car name colour  seats     cost
# 0   Toyota    red      4   154000
# 1   Suzuki  black      5   164000
# 2    Honda  white      4  5460000

# %%
car_sales.loc[3]
# Out:
# car name          BMW
# colour           gray
# seats               5
# cost        100000000
# Name: 3, dtype: object

# %%
car_sales.loc[:3]
# Out:
#   car name colour  seats       cost
# 0   Toyota    red      4     154000
# 1   Suzuki  black      5     164000
# 2    Honda  white      4    5460000
# 3      BMW   gray      5  100000000

# %%
car_sales.loc[3:]
# Out:
#   car name  colour  seats       cost
# 3      BMW    gray      5  100000000
# 4     Audi   white      4     546218
# 5     Nano  yellow      6     543261

# %%
car_sales.iloc[3]
# Out:
# car name          BMW
# colour           gray
# seats               5
# cost        100000000
# Name: 3, dtype: object

# %%
car_sales["cost"]
# Out:
# 0       154000
# 1       164000
# 2      5460000
# 3    100000000
# 4       546218
# 5       543261
# Name: cost, dtype: int64

# %%
car_sales[car_sales["cost"]>780000]
# Out:
#   car name colour  seats       cost
# 2    Honda  white      4    5460000
# 3      BMW   gray      5  100000000

# %%
car_sales
# Out:
#   car name  colour  seats       cost
# 0   Toyota     red      4     154000
# 1   Suzuki   black      5     164000
# 2    Honda   white      4    5460000
# 3      BMW    gray      5  100000000
# 4     Audi   white      4     546218
# 5     Nano  yellow      6     543261

# %%
pd.crosstab(car_sales["car name"],car_sales["seats"])
# Out:
# seats     4  5  6
# car name
# Audi      1  0  0
# BMW       0  1  0
# Honda     1  0  0
# Nano      0  0  1
# Suzuki    0  1  0
# Toyota    1  0  0

# %%
car_sales.groupby(["car name"]).mean()
# Out:
#           seats       cost
# car name
# Audi          4     546218
# BMW           5  100000000
# Honda         4    5460000
# Nano          6     543261
# Suzuki        5     164000
# Toyota        4     154000

# %%
car_sales
# Out:
#   car name  colour  seats       cost
# 0   Toyota     red      4     154000
# 1   Suzuki   black      5     164000
# 2    Honda   white      4    5460000
# 3      BMW    gray      5  100000000
# 4     Audi   white      4     546218
# 5     Nano  yellow      6     543261

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## plot

# %%
car_sales["cost"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["seats"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["odometer"]={"22300","25000","27000","18000","12345","15003"}

# %%
car_sales
# Out:
#   car name  colour  seats       cost odometer
# 0   Toyota     red      4     154000    27000
# 1   Suzuki   black      5     164000    12345
# 2    Honda   white      4    5460000    18000
# 3      BMW    gray      5  100000000    15003
# 4     Audi   white      4     546218    22300
# 5     Nano  yellow      6     543261    25000

# %%
car_sales["odometer"]=car_sales["odometer"].astype(str).astype(int)

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   car name  6 non-null      object
#  1   colour    6 non-null      object
#  2   seats     6 non-null      int64
#  3   cost      6 non-null      int64
#  4   odometer  6 non-null      int32
# dtypes: int32(1), int64(2), object(2)
# memory usage: 344.0+ bytes

# %%
car_sales["odometer"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["odometer"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating data

# %%
car_sales["car name"].str.lower()
# Out:
# 0    toyota
# 1    suzuki
# 2     honda
# 3       bmw
# 4      audi
# 5      nano
# Name: car name, dtype: object

# %%
car_sales["car name"].str.upper()
# Out:
# 0    TOYOTA
# 1    SUZUKI
# 2     HONDA
# 3       BMW
# 4      AUDI
# 5      NANO
# Name: car name, dtype: object

# %%
car_sales_missing_data=pd.read_csv("car-sales-missing-data.csv")
car_sales_missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_data["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_data["Odometer"].fillna(car_sales_missing_data["Odometer"].mean(),inplace=False)
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      9 non-null      object
#  1   Colour    9 non-null      object
#  2   Odometer  10 non-null     float64
#  3   Doors     9 non-null      float64
#  4   Price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales_missing_data.dropna(inplace=True)

# %%
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales
# Out:
#   car name  colour  seats       cost  odometer
# 0   Toyota     red      4     154000     27000
# 1   Suzuki   black      5     164000     12345
# 2    Honda   white      4    5460000     18000
# 3      BMW    gray      5  100000000     15003
# 4     Audi   white      4     546218     22300
# 5     Nano  yellow      6     543261     25000

# %% [markdown]
# ## add columns to the data
# two methods
# 1. by direct example with doors
# 2.by example with available place

# %%
car_sales
# Out:
#   car name  colour  seats       cost  odometer
# 0   Toyota     red      4     154000     27000
# 1   Suzuki   black      5     164000     12345
# 2    Honda   white      4    5460000     18000
# 3      BMW    gray      5  100000000     15003
# 4     Audi   white      4     546218     22300
# 5     Nano  yellow      6     543261     25000

# %%
car_sales["Places"]={"IND","AUS","IND","VZG","BZA","HYD","KKD"}

# %%
car_sales
# Out:
#   car name  colour  seats       cost  odometer Places
# 0   Toyota     red      4     154000     27000    KKD
# 1   Suzuki   black      5     164000     12345    BZA
# 2    Honda   white      4    5460000     18000    VZG
# 3      BMW    gray      5  100000000     15003    AUS
# 4     Audi   white      4     546218     22300    IND
# 5     Nano  yellow      6     543261     25000    HYD

# %%
Doors=pd.Series([5,5,5,4])
car_sales["Doors"]=Doors

# %%
car_sales
# Out:
#   car name  colour  seats       cost  odometer Places  Doors
# 0   Toyota     red      4     154000     27000    KKD    5.0
# 1   Suzuki   black      5     164000     12345    BZA    5.0
# 2    Honda   white      4    5460000     18000    VZG    5.0
# 3      BMW    gray      5  100000000     15003    AUS    4.0
# 4     Audi   white      4     546218     22300    IND    NaN
# 5     Nano  yellow      6     543261     25000    HYD    NaN

# %%
car_sales["Doors"].fillna(5,inplace=True)

# %%
car_sales
# Out:
#   car name  colour  seats       cost  odometer Places  Doors
# 0   Toyota     red      4     154000     27000    KKD    5.0
# 1   Suzuki   black      5     164000     12345    BZA    5.0
# 2    Honda   white      4    5460000     18000    VZG    5.0
# 3      BMW    gray      5  100000000     15003    AUS    4.0
# 4     Audi   white      4     546218     22300    IND    5.0
# 5     Nano  yellow      6     543261     25000    HYD    5.0

# %% [markdown]
# #### add column from list

# %%
fuel_economy=[7.2,5.6,6.8,7.5,8.7,4.5]
car_sales["Fuel_Economy per 100KM"]=fuel_economy

# %%
car_sales
# Out:
#   car name  colour  seats       cost  odometer Places  Doors  Fuel_Economy  \
# 0   Toyota     red      4     154000     27000    KKD    5.0           7.2
# 1   Suzuki   black      5     164000     12345    BZA    5.0           5.6
# 2    Honda   white      4    5460000     18000    VZG    5.0           6.8
# 3      BMW    gray      5  100000000     15003    AUS    4.0           7.5
# 4     Audi   white      4     546218     22300    IND    5.0           8.7
# 5     Nano  yellow      6     543261     25000    HYD    5.0           4.5
#
#    Fuel_Economy per 100KM
# 0                     7.2
# 1                     5.6
# 2                     6.8
# 3                     7.5
# 4                     8.7
# 5                     4.5

# %%
car_sales["Total_Fuel_used"]=car_sales["odometer"]/100 * car_sales["Fuel_Economy"]

# %%
car_sales
# Out:
#   car name  colour  seats       cost  odometer Places  Doors  Fuel_Economy  \
# 0   Toyota     red      4     154000     27000    KKD    5.0           7.2
# 1   Suzuki   black      5     164000     12345    BZA    5.0           5.6
# 2    Honda   white      4    5460000     18000    VZG    5.0           6.8
# 3      BMW    gray      5  100000000     15003    AUS    4.0           7.5
# 4     Audi   white      4     546218     22300    IND    5.0           8.7
# 5     Nano  yellow      6     543261     25000    HYD    5.0           4.5
#
#    Fuel_Economy per 100KM  Total_Fuel_used
# 0                     7.2         1944.000
# 1                     5.6          691.320
# 2                     6.8         1224.000
# 3                     7.5         1125.225
# 4                     8.7         1940.100
# 5                     4.5         1125.000

# %%
car_sales["no.of wheels"]=4
car_sales
# Out:
#   car name  colour  seats       cost  odometer Places  Doors  Fuel_Economy  \
# 0   Toyota     red      4     154000     27000    KKD    5.0           7.2
# 1   Suzuki   black      5     164000     12345    BZA    5.0           5.6
# 2    Honda   white      4    5460000     18000    VZG    5.0           6.8
# 3      BMW    gray      5  100000000     15003    AUS    4.0           7.5
# 4     Audi   white      4     546218     22300    IND    5.0           8.7
# 5     Nano  yellow      6     543261     25000    HYD    5.0           4.5
#
#    Fuel_Economy per 100KM  Total_Fuel_used  no.of wheels
# 0                     7.2         1944.000             4
# 1                     5.6          691.320             4
# 2                     6.8         1224.000             4
# 3                     7.5         1125.225             4
# 4                     8.7         1940.100             4
# 5                     4.5         1125.000             4

# %%
car_sales["Passed road safety"]=True
car_sales
# Out:
#   car name  colour  seats       cost  odometer Places  Doors  Fuel_Economy  \
# 0   Toyota     red      4     154000     27000    KKD    5.0           7.2
# 1   Suzuki   black      5     164000     12345    BZA    5.0           5.6
# 2    Honda   white      4    5460000     18000    VZG    5.0           6.8
# 3      BMW    gray      5  100000000     15003    AUS    4.0           7.5
# 4     Audi   white      4     546218     22300    IND    5.0           8.7
# 5     Nano  yellow      6     543261     25000    HYD    5.0           4.5
#
#    Fuel_Economy per 100KM  Total_Fuel_used  no.of wheels  Passed road safety
# 0                     7.2         1944.000             4                True
# 1                     5.6          691.320             4                True
# 2                     6.8         1224.000             4                True
# 3                     7.5         1125.225             4                True
# ...

# %%
car_sales.dtypes
# Out:
# car name                   object
# colour                     object
# seats                       int64
# cost                        int64
# odometer                    int32
# Places                     object
# Doors                     float64
# Fuel_Economy              float64
# Fuel_Economy per 100KM    float64
# Total_Fuel_used           float64
# no.of wheels                int64
# Passed road safety           bool
# dtype: object

# %%
car_sales=car_sales.drop("Fuel_Economy",axis=1)

# %%
car_sales
# Out:
#   car name  colour  seats       cost  odometer Places  Doors  \
# 0   Toyota     red      4     154000     27000    KKD    5.0
# 1   Suzuki   black      5     164000     12345    BZA    5.0
# 2    Honda   white      4    5460000     18000    VZG    5.0
# 3      BMW    gray      5  100000000     15003    AUS    4.0
# 4     Audi   white      4     546218     22300    IND    5.0
# 5     Nano  yellow      6     543261     25000    HYD    5.0
#
#    Fuel_Economy per 100KM  Total_Fuel_used  no.of wheels  Passed road safety
# 0                     7.2         1944.000             4                True
# 1                     5.6          691.320             4                True
# 2                     6.8         1224.000             4                True
# 3                     7.5         1125.225             4                True
# 4                     8.7         1940.100             4                True
# 5                     4.5         1125.000             4                True

# %%
car_sales_shuffled=car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#   car name  colour  seats       cost  odometer Places  Doors  \
# 1   Suzuki   black      5     164000     12345    BZA    5.0
# 3      BMW    gray      5  100000000     15003    AUS    4.0
# 5     Nano  yellow      6     543261     25000    HYD    5.0
# 2    Honda   white      4    5460000     18000    VZG    5.0
# 4     Audi   white      4     546218     22300    IND    5.0
# 0   Toyota     red      4     154000     27000    KKD    5.0
#
#    Fuel_Economy per 100KM  Total_Fuel_used  no.of wheels  Passed road safety
# 1                     5.6          691.320             4                True
# 3                     7.5         1125.225             4                True
# 5                     4.5         1125.000             4                True
# 2                     6.8         1224.000             4                True
# 4                     8.7         1940.100             4                True
# 0                     7.2         1944.000             4                True

# %%
car_sales_shuffled.to_csv("car-sales-shuffled-data.csv")

# %%
car_sales.sample(frac=0.5)
# Out:
#   car name  colour  seats     cost  odometer Places  Doors  \
# 5     Nano  yellow      6   543261     25000    HYD    5.0
# 2    Honda   white      4  5460000     18000    VZG    5.0
# 0   Toyota     red      4   154000     27000    KKD    5.0
#
#    Fuel_Economy per 100KM  Total_Fuel_used  no.of wheels  Passed road safety
# 5                     4.5           1125.0             4                True
# 2                     6.8           1224.0             4                True
# 0                     7.2           1944.0             4                True

# %%
car_sales.reset_index(drop=True,inplace=False)
# Out:
#    index car name  colour  seats       cost  odometer Places  Doors  \
# 0      0   Toyota     red      4     154000     27000    KKD    5.0
# 1      1   Suzuki   black      5     164000     12345    BZA    5.0
# 2      2    Honda   white      4    5460000     18000    VZG    5.0
# 3      3      BMW    gray      5  100000000     15003    AUS    4.0
# 4      4     Audi   white      4     546218     22300    IND    5.0
# 5      5     Nano  yellow      6     543261     25000    HYD    5.0
#
#    Fuel_Economy per 100KM  Total_Fuel_used  no.of wheels  Passed road safety
# 0                     7.2         1944.000             4                True
# 1                     5.6          691.320             4                True
# 2                     6.8         1224.000             4                True
# 3                     7.5         1125.225             4                True
# 4                     8.7         1940.100             4                True
# ...

# %%
car_sales
# Out:
#    index car name  colour  seats       cost  odometer Places  Doors  \
# 0      0   Toyota     red      4     154000     27000    KKD    5.0
# 1      1   Suzuki   black      5     164000     12345    BZA    5.0
# 2      2    Honda   white      4    5460000     18000    VZG    5.0
# 3      3      BMW    gray      5  100000000     15003    AUS    4.0
# 4      4     Audi   white      4     546218     22300    IND    5.0
# 5      5     Nano  yellow      6     543261     25000    HYD    5.0
#
#    Fuel_Economy per 100KM  Total_Fuel_used  no.of wheels  Passed road safety
# 0                     7.2         1944.000             4                True
# 1                     5.6          691.320             4                True
# 2                     6.8         1224.000             4                True
# 3                     7.5         1125.225             4                True
# 4                     8.7         1940.100             4                True
# ...

# %%
car_sales["odometer"]=car_sales["odometer"].apply(lambda x: x/1.6)
car_sales
# Out:
#    index car name  colour  seats       cost   odometer Places  Doors  \
# 0      0   Toyota     red      4     154000  16875.000    KKD    5.0
# 1      1   Suzuki   black      5     164000   7715.625    BZA    5.0
# 2      2    Honda   white      4    5460000  11250.000    VZG    5.0
# 3      3      BMW    gray      5  100000000   9376.875    AUS    4.0
# 4      4     Audi   white      4     546218  13937.500    IND    5.0
# 5      5     Nano  yellow      6     543261  15625.000    HYD    5.0
#
#    Fuel_Economy per 100KM  Total_Fuel_used  no.of wheels  Passed road safety
# 0                     7.2         1944.000             4                True
# 1                     5.6          691.320             4                True
# 2                     6.8         1224.000             4                True
# 3                     7.5         1125.225             4                True
# 4                     8.7         1940.100             4                True
# ...
