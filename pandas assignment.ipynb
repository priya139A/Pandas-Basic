# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="assigment03")
# Out:
# [jovian] Attempting to save notebook..

# %%
import pandas as pd

# %%
from urllib.request import urlretrieve

urlretrieve('https://hub.jovian.ml/wp-content/uploads/2020/09/countries.csv', 
            'countries.csv')
# Out:
# ('countries.csv', <http.client.HTTPMessage at 0x188e32f00a0>)

# %%
countries_df = pd.read_csv('countries.csv')

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %% [markdown]
# ### Q1

# %%
num_countries=countries_df.shape[0]

# %%
print('There are {} countries in the dataset'.format(num_countries))
# Out:
# There are 210 countries in the dataset

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# ### Q2

# %%
continents=pd.unique(countries_df["continent"])

# %%
continents
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %%
total_population = countries_df["population"].sum()

# %%
total_population
# Out:
# 7757980095.0

# %%
print('The total population is {}.'.format(int(total_population)))
# Out:
# The total population is 7757980095.

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# ###Q3

# %%
countries_df.isnull().sum()
# Out:
# location                       0
# continent                      0
# population                     0
# life_expectancy                3
# hospital_beds_per_thousand    46
# gdp_per_capita                27
# dtype: int64

# %%
# there are 3 null in life expectancy, we will replace the null with mean value
countries_df["life_expectancy"].fillna(countries_df["life_expectancy"].mean(),inplace = True)

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                          0.50        1803.987
# 1                          2.89       11803.431
# 2                          1.90       13913.839
# 3                           NaN             NaN
# ...

# %%
countries_df["weighted_life_expectancy"]=countries_df["population"]*countries_df["life_expectancy"]

# %%
print('The  overall life expectancy across in the world {}.'.format(countries_df["weighted_life_expectancy"].sum()/len(countries_df["weighted_life_expectancy"])))
# Out:
# The  overall life expectancy across in the world 2687274318.9487233.

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %%
most_populous=countries_df.nlargest(10,["population"])

# %%
most_populous
# Out:
#           location      continent    population  life_expectancy  \
# 41           China           Asia  1.439324e+09            76.91
# 90           India           Asia  1.380004e+09            69.66
# 199  United States  North America  3.310026e+08            78.86
# 91       Indonesia           Asia  2.735236e+08            71.72
# 145       Pakistan           Asia  2.208923e+08            67.27
# 27          Brazil  South America  2.125594e+08            75.88
# 141        Nigeria         Africa  2.061396e+08            54.69
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 157         Russia         Europe  1.459345e+08            72.58
# 125         Mexico  North America  1.289328e+08            75.05
#
#      hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy
# 41                         4.34       15308.712              1.106984e+11
# 90                         0.53        6426.674              9.613111e+10
# ...

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %%
countries_df["overall_gdp"]=countries_df["population"]*countries_df["gdp_per_capita"]

# %%
countries_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy  \
# 0                          0.50        1803.987              2.523724e+09
# 1                          2.89       11803.431              2.261087e+08
# ...

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# ### Q: (Optional) Create a dataframe containing 10 countries with the lowest GDP per capita, among the counties with population greater than 100 million.

# %%
countries_df1=countries_df[countries_df["population"] > 1000000000 ]

# %%
countries_df1
# Out:
#    location continent    population  life_expectancy  \
# 41    China      Asia  1.439324e+09            76.91
# 90    India      Asia  1.380004e+09            69.66
#
#     hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy  \
# 41                        4.34       15308.712              1.106984e+11
# 90                        0.53        6426.674              9.613111e+10
#
#      overall_gdp
# 41  2.203419e+13
# 90  8.868838e+12

# %% [markdown]
# #### There are only two countries in the dataset having populaton greater than 100 million

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# **Q: Create a data frame that counts the number countries in each continent?**
#
# *Hint: Use `groupby`, select the `location` column and aggregate using `count`.*

# %%
countries_counts = countries_df.groupby(["continent"]).size().to_frame().rename(columns={"continent":"continent",0:"count"})

# %%
countries_counts
# Out:
#                count
# continent
# Africa            55
# Asia              47
# Europe            51
# North America     36
# Oceania            8
# South America     13

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# **Q7: Create a data frame showing the total population of each continent.**
#
# *Hint: Use `groupby`, select the population column and aggregate using `sum`.*

# %%
continent_populations_df = countries_df.groupby(["continent"]).sum().reset_index()[["continent","population"]]

# %%
continent_populations_df
# Out:
#        continent    population
# 0         Africa  1.339424e+09
# 1           Asia  4.607388e+09
# 2         Europe  7.485062e+08
# 3  North America  5.912425e+08
# 4        Oceania  4.095832e+07
# 5  South America  4.304611e+08

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %%
urlretrieve('https://hub.jovian.ml/wp-content/uploads/2020/09/covid-countries-data.csv', 
            'covid-countries-data.csv')
# Out:
# ('covid-countries-data.csv', <http.client.HTTPMessage at 0x188e3633bb0>)

# %%
covid_data_df = pd.read_csv('covid-countries-data.csv')

# %%
covid_data_df
# Out:
#            location  total_cases  total_deaths  total_tests
# 0       Afghanistan      38243.0        1409.0          NaN
# 1           Albania       9728.0         296.0          NaN
# 2           Algeria      45158.0        1525.0          NaN
# 3           Andorra       1199.0          53.0          NaN
# 4            Angola       2729.0         109.0          NaN
# ..              ...          ...           ...          ...
# 207  Western Sahara        766.0           1.0          NaN
# 208           World   26059065.0      863535.0          NaN
# 209           Yemen       1976.0         571.0          NaN
# 210          Zambia      12415.0         292.0          NaN
# 211        Zimbabwe       6638.0         206.0      97272.0
#
# [212 rows x 4 columns]

# %% [markdown]
# **Q8: Count the number of countries for which the `total_tests` data is missing.**
#
# *Hint: Use the `.isna` method.*

# %%
total_tests_missing=countries_df.isna().sum()['location']

# %%
print("The data for total tests is missing for {} countries.".format(int(total_tests_missing)))
# Out:
# The data for total tests is missing for 0 countries.

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# Let's merge the two data frames, and compute some more metrics.
#
# **Q9: Merge `countries_df` with `covid_data_df` on the `location` column.**
#
# *Hint: Use the `.merge` method on `countries_df`.

# %%
combined_df=countries_df.merge(covid_data_df)

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy  \
# 0                          0.50        1803.987              2.523724e+09
# 1                          2.89       11803.431              2.261087e+08
# ...

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy  \
# 0                          0.50        1803.987              2.523724e+09
# 1                          2.89       11803.431              2.261087e+08
# ...

# %% [markdown]
# **Q10: Add columns `tests_per_million`, `cases_per_million` and `deaths_per_million` into `combined_df`.**

# %%
combined_df["tests_per_million"]=combined_df["total_tests"]*10000000/combined_df["population"]

# %%
combined_df["cases_per_million"]=combined_df["total_cases"]*10000000/combined_df["population"]
combined_df["deaths_per_million"]=combined_df["total_deaths"]*10000000/combined_df["population"]

# %%
combined_df
# Out:
#            location continent  population  life_expectancy  \
# 0       Afghanistan      Asia  38928341.0            64.83
# 1           Albania    Europe   2877800.0            78.57
# 2           Algeria    Africa  43851043.0            76.88
# 3           Andorra    Europe     77265.0            83.73
# 4            Angola    Africa  32866268.0            61.15
# ..              ...       ...         ...              ...
# 205         Vietnam      Asia  97338583.0            75.40
# 206  Western Sahara    Africa    597330.0            70.26
# 207           Yemen      Asia  29825968.0            66.12
# 208          Zambia    Africa  18383956.0            63.89
# 209        Zimbabwe    Africa  14862927.0            61.49
#
#      hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy  \
# 0                          0.50        1803.987              2.523724e+09
# 1                          2.89       11803.431              2.261087e+08
# ...

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# **Q11: Create a dataframe with 10 countires that have highest number of tests per million people.**

# %%
highest_tests_df = combined_df.nlargest(10,["tests_per_million"])

# %%
highest_tests_df
# Out:
#                  location      continent   population  life_expectancy  \
# 197  United Arab Emirates           Asia    9890400.0            77.97
# 14                Bahrain           Asia    1701583.0            77.29
# 115            Luxembourg         Europe     625976.0            82.25
# 122                 Malta         Europe     441539.0            82.53
# 53                Denmark         Europe    5792203.0            80.90
# 96                 Israel           Asia    8655541.0            82.97
# 89                Iceland         Europe     341250.0            82.99
# 157                Russia         Europe  145934460.0            72.58
# 199         United States  North America  331002647.0            78.86
# 10              Australia        Oceania   25499881.0            83.44
#
#      hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy  \
# 197                       1.200       67293.483              7.711545e+08
# ...

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# **Q12: Create a dataframe with 10 countires that have highest number of positive cases per million people.**

# %%
highest_cases_df = combined_df.nlargest(10,["cases_per_million"])

# %%
highest_cases_df
# Out:
#           location      continent   population  life_expectancy  \
# 155          Qatar           Asia    2881060.0            80.23
# 14         Bahrain           Asia    1701583.0            77.29
# 147         Panama  North America    4314768.0            78.51
# 40           Chile  South America   19116209.0            80.18
# 162     San Marino         Europe      33938.0            84.97
# 9            Aruba  North America     106766.0            76.29
# 105         Kuwait           Asia    4270563.0            75.49
# 150           Peru  South America   32971846.0            76.74
# 27          Brazil  South America  212559409.0            75.88
# 199  United States  North America  331002647.0            78.86
#
#      hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy  \
# 155                        1.20      116935.600              2.311474e+08
# 14                         2.00       43290.705              1.315154e+08
# ...

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# **Q13: Create a dataframe with 10 countires that have highest number of deaths cases per million people?**

# %%
highest_deaths_df = combined_df.nlargest(10,["deaths_per_million"])

# %%
highest_deaths_df
# Out:
#            location      continent   population  life_expectancy  \
# 162      San Marino         Europe      33938.0            84.97
# 150            Peru  South America   32971846.0            76.74
# 18          Belgium         Europe   11589616.0            81.63
# 3           Andorra         Europe      77265.0            83.73
# 177           Spain         Europe   46754783.0            83.56
# 198  United Kingdom         Europe   67886004.0            81.32
# 40            Chile  South America   19116209.0            80.18
# 97            Italy         Europe   60461828.0            83.51
# 27           Brazil  South America  212559409.0            75.88
# 182          Sweden         Europe   10099270.0            82.80
#
#      hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy  \
# 162                        3.80       56861.470              2.883712e+06
# 150                        1.60       12236.706              2.530259e+09
# ...

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %% [markdown]
# **(Optional) Q: Count number of countries that feature in both the lists "20 countries with lowest GDP per capita" and "20 countries with the lowest number of hospital beds per thousand population". Only consider countries with a population higher than 10 million while creating the list.**

# %%
combined_df_extra=combined_df[combined_df["population"]>100000000]

# %%
combined_df_extra
# Out:
#           location      continent    population  life_expectancy  \
# 15      Bangladesh           Asia  1.646894e+08            72.59
# 27          Brazil  South America  2.125594e+08            75.88
# 41           China           Asia  1.439324e+09            76.91
# 58           Egypt         Africa  1.023344e+08            71.99
# 63        Ethiopia         Africa  1.149636e+08            66.60
# 90           India           Asia  1.380004e+09            69.66
# 91       Indonesia           Asia  2.735236e+08            71.72
# 99           Japan           Asia  1.264765e+08            84.63
# 125         Mexico  North America  1.289328e+08            75.05
# 141        Nigeria         Africa  2.061396e+08            54.69
# 145       Pakistan           Asia  2.208923e+08            67.27
# 151    Philippines           Asia  1.095811e+08            71.23
# 157         Russia         Europe  1.459345e+08            72.58
# ...

# %%
combines_df11=combined_df.nsmallest(20,["gdp_per_capita"])
combines_df11
# Out:
#                          location      continent   population  \
# 38       Central African Republic         Africa    4829764.0
# 32                        Burundi         Africa   11890781.0
# 111                       Liberia         Africa    5057677.0
# 52   Democratic Republic of Congo         Africa   89561404.0
# 140                         Niger         Africa   24206636.0
# 118                        Malawi         Africa   19129955.0
# 132                    Mozambique         Africa   31255435.0
# 168                  Sierra Leone         Africa    7976985.0
# 43                        Comoros         Africa     869595.0
# 117                    Madagascar         Africa   27691019.0
# 190                          Togo         Africa    8278737.0
# 207                         Yemen           Asia   29825968.0
# 61                        Eritrea         Africa    3546427.0
# 83                  Guinea-Bissau         Africa    1967998.0
# ...

# %%
countries_counts = combines_df11.groupby(["location"]).size().to_frame().rename(columns={"continent":"continent",0:"count"})

# %%
countries_counts
# Out:
#                               count
# location
# Burkina Faso                      1
# Burundi                           1
# Central African Republic          1
# Comoros                           1
# Democratic Republic of Congo      1
# Eritrea                           1
# Ethiopia                          1
# Gambia                            1
# Guinea-Bissau                     1
# Haiti                             1
# Liberia                           1
# Madagascar                        1
# Malawi                            1
# Mozambique                        1
# Niger                             1
# Sierra Leone                      1
# South Sudan                       1
# Togo                              1
# Uganda                            1
# Yemen                             1

# %%
combines_df12=combined_df.nsmallest(20,["hospital_beds_per_thousand"])
combines_df12
# Out:
#          location      continent    population  life_expectancy  \
# 121          Mali         Africa  2.025083e+07            59.31
# 117    Madagascar         Africa  2.769102e+07            67.04
# 63       Ethiopia         Africa  1.149636e+08            66.60
# 82         Guinea         Africa  1.313279e+07            61.60
# 135         Nepal           Asia  2.913681e+07            70.78
# 140         Niger         Africa  2.420664e+07            62.42
# 31   Burkina Faso         Africa  2.090328e+07            61.58
# 0     Afghanistan           Asia  3.892834e+07            64.83
# 20          Benin         Africa  1.212320e+07            61.77
# 195        Uganda         Africa  4.574100e+07            63.37
# 90          India           Asia  1.380004e+09            69.66
# 80      Guatemala  North America  1.791557e+07            74.30
# 145      Pakistan           Asia  2.208923e+08            67.27
# 61        Eritrea         Africa  3.546427e+06            66.32
# ...

# %%
countries_counts_2 = combines_df12.groupby(["location"]).size().to_frame().rename(columns={"continent":"location",0:"count"})

# %%
countries_counts_2
# Out:
#               count
# location
# Afghanistan       1
# Benin             1
# Burkina Faso      1
# Eritrea           1
# Ethiopia          1
# Guatemala         1
# Guinea            1
# Haiti             1
# Honduras          1
# India             1
# Madagascar        1
# Mali              1
# Mozambique        1
# Nepal             1
# Niger             1
# Pakistan          1
# Tanzania          1
# Togo              1
# Uganda            1
# Yemen             1

# %%
combined_df_extra1=pd.merge(countries_counts,countries_counts_2, how='inner',on='location')

# %%
combined_df_extra1
# Out:
#               count_x  count_y
# location
# Burkina Faso        1        1
# Eritrea             1        1
# Ethiopia            1        1
# Haiti               1        1
# Madagascar          1        1
# Mozambique          1        1
# Niger               1        1
# Togo                1        1
# Uganda              1        1
# Yemen               1        1

# %%
combined_df=pd.merge(combined_df_extra,combined_df_extra1,how='inner',on='location')

# %%
combined_df
# Out:
#    location continent   population  life_expectancy  \
# 0  Ethiopia    Africa  114963583.0             66.6
#
#    hospital_beds_per_thousand  gdp_per_capita  weighted_life_expectancy  \
# 0                         0.3        1729.927              7.656575e+09
#
#     overall_gdp  total_cases  total_deaths  total_tests  tests_per_million  \
# 0  1.988786e+11      54409.0         846.0     869430.0       75626.557325
#
#    cases_per_million  deaths_per_million  count_x  count_y
# 0        4732.716098           73.588521        1        1

# %%
import jovian

# %%
jovian.commit(project='assignment03', environment=None)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# 'https://jovian.ai/hepsisolmon13/assignment03'

# %%
jovian.submit(assignment="zero-to-pandas-a3")
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "hepsisolmon13/assignment03" on https://jovian.ai/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Error: Failed to read Anaconda environment using command: "conda env export -n C:\Users\hepsi priya\desktop\sample_project\env --no-builds"
# [jovian] Committed successfully! https://jovian.ai/hepsisolmon13/assignment03
# [jovian] Submitting assignment..
# [jovian] Verify your submission at https://jovian.ai/learn/data-analysis-with-python-zero-to-pandas/assignment/assignment-3-pandas-practice
